# %%
import os, sys
from google.colab import drive
drive.mount('/content/drive')
nb_path = '/content/notebooks'
os.symlink('/content/drive/My Drive/Colab Notebooks', nb_path)
sys.path.insert(0,nb_path)
# Out:
# Mounted at /content/drive

# %%
# !pip uninstall tensorflow tensorflow-tensorboard tensorflow-estimator
# !pip install tensorflow==1.15.0
# Out:
# Found existing installation: tensorflow 2.6.0
# Uninstalling tensorflow-2.6.0:

# %%
# !pip install --target=$nb_path pycaret
# Out:
# Collecting pycaret
#   Downloading pycaret-2.3.3-py3-none-any.whl (264 kB)
#      |████████████████████████████████| 264 kB 34.2 MB/s
# Collecting scipy<=1.5.4
#   Downloading scipy-1.5.4-cp37-cp37m-manylinux1_x86_64.whl (25.9 MB)
#      |████████████████████████████████| 25.9 MB 906 bytes/s
# Collecting pandas-profiling>=2.8.0
#   Downloading pandas_profiling-3.0.0-py2.py3-none-any.whl (248 kB)
#      |████████████████████████████████| 248 kB 53.5 MB/s
# Collecting yellowbrick>=1.0.1
#   Downloading yellowbrick-1.3.post1-py3-none-any.whl (271 kB)
#      |████████████████████████████████| 271 kB 52.6 MB/s
# Collecting mlxtend>=0.17.0
#   Downloading mlxtend-0.19.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 34.2 MB/s
# Collecting imbalanced-learn==0.7.0
#   Downloading imbalanced_learn-0.7.0-py3-none-any.whl (167 kB)
#      |████████████████████████████████| 167 kB 56.3 MB/s
# Collecting nltk
#   Downloading nltk-3.6.2-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 30.2 MB/s
# Collecting ipywidgets
#   Downloading ipywidgets-7.6.4-py2.py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 54.1 MB/s
# Collecting scikit-plot
#   Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Collecting plotly>=4.4.1
#   Downloading plotly-5.3.1-py2.py3-none-any.whl (23.9 MB)
#      |████████████████████████████████| 23.9 MB 1.2 MB/s
# Collecting mlflow
#   Downloading mlflow-1.20.2-py3-none-any.whl (14.6 MB)
#      |████████████████████████████████| 14.6 MB 106 kB/s
# Collecting numpy==1.19.5
#   Downloading numpy-1.19.5-cp37-cp37m-manylinux2010_x86_64.whl (14.8 MB)
#      |████████████████████████████████| 14.8 MB 167 kB/s
# Collecting umap-learn
#   Downloading umap-learn-0.5.1.tar.gz (80 kB)
#      |████████████████████████████████| 80 kB 237 kB/s
# Collecting kmodes>=0.10.1
#   Downloading kmodes-0.11.0-py2.py3-none-any.whl (18 kB)
# Collecting pandas
#   Downloading pandas-1.3.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 32.3 MB/s
# Collecting scikit-learn==0.23.2
#   Downloading scikit_learn-0.23.2-cp37-cp37m-manylinux1_x86_64.whl (6.8 MB)
#      |████████████████████████████████| 6.8 MB 27.2 MB/s
# Collecting seaborn
#   Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
#      |████████████████████████████████| 292 kB 54.9 MB/s
# Collecting spacy<2.4.0
#   Downloading spacy-2.3.7-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.4 MB)
#      |████████████████████████████████| 10.4 MB 16.2 MB/s
# Collecting Boruta
#   Downloading Boruta-0.3-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 4.6 MB/s
# Collecting IPython
#   Downloading ipython-7.27.0-py3-none-any.whl (787 kB)
#      |████████████████████████████████| 787 kB 43.9 MB/s
# Collecting pyod
#   Downloading pyod-0.9.3.tar.gz (111 kB)
#      |████████████████████████████████| 111 kB 63.0 MB/s
# Collecting joblib
#   Downloading joblib-1.0.1-py3-none-any.whl (303 kB)
#      |████████████████████████████████| 303 kB 71.6 MB/s
# Collecting wordcloud
#   Downloading wordcloud-1.8.1-cp37-cp37m-manylinux1_x86_64.whl (366 kB)
#      |████████████████████████████████| 366 kB 76.8 MB/s
# Collecting cufflinks>=0.17.0
#   Downloading cufflinks-0.17.3.tar.gz (81 kB)
#      |████████████████████████████████| 81 kB 9.6 MB/s
# Collecting lightgbm>=2.3.1
#   Downloading lightgbm-3.2.1-py3-none-manylinux1_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 43.0 MB/s
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.3.1.tar.gz (1.7 MB)
#      |████████████████████████████████| 1.7 MB 34.7 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Collecting textblob
#   Downloading textblob-0.15.3-py2.py3-none-any.whl (636 kB)
#      |████████████████████████████████| 636 kB 64.3 MB/s
# Collecting matplotlib
#   Downloading matplotlib-3.4.3-cp37-cp37m-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 36.5 MB/s
# Collecting gensim<4.0.0
#   Downloading gensim-3.8.3-cp37-cp37m-manylinux1_x86_64.whl (24.2 MB)
#      |████████████████████████████████| 24.2 MB 104 kB/s
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-2.2.0-py3-none-any.whl (12 kB)
# Collecting six>=1.9.0
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting colorlover>=0.2.1
#   Downloading colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Collecting setuptools>=34.4.1
#   Using cached setuptools-58.0.4-py3-none-any.whl (816 kB)
# Collecting smart-open>=1.8.1
#   Downloading smart_open-5.2.1-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 5.9 MB/s
# Collecting pexpect>4.3
#   Downloading pexpect-4.8.0-py2.py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 6.1 MB/s
# Collecting prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0
#   Downloading prompt_toolkit-3.0.20-py3-none-any.whl (370 kB)
#      |████████████████████████████████| 370 kB 54.0 MB/s
# Collecting jedi>=0.16
#   Downloading jedi-0.18.0-py2.py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 54.8 MB/s
# Collecting traitlets>=4.2
#   Downloading traitlets-5.1.0-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 10.9 MB/s
# Collecting matplotlib-inline
#   Downloading matplotlib_inline-0.1.3-py3-none-any.whl (8.2 kB)
# Collecting backcall
#   Downloading backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting pickleshare
#   Downloading pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Collecting pygments
#   Downloading Pygments-2.10.0-py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 56.0 MB/s
# Collecting decorator
#   Downloading decorator-5.1.0-py3-none-any.whl (9.1 kB)
# Collecting widgetsnbextension~=3.5.0
#   Downloading widgetsnbextension-3.5.1-py2.py3-none-any.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 45.4 MB/s
# Collecting ipykernel>=4.5.1
#   Downloading ipykernel-6.4.1-py3-none-any.whl (124 kB)
#      |████████████████████████████████| 124 kB 53.7 MB/s
# Collecting nbformat>=4.2.0
#   Downloading nbformat-5.1.3-py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 78.4 MB/s
# Collecting ipython-genutils~=0.2.0
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting jupyterlab-widgets>=1.0.0
#   Downloading jupyterlab_widgets-1.0.1-py3-none-any.whl (243 kB)
#      |████████████████████████████████| 243 kB 69.8 MB/s
# Collecting argcomplete>=1.12.3
#   Downloading argcomplete-1.12.3-py2.py3-none-any.whl (38 kB)
# Collecting tornado<7.0,>=4.2
#   Downloading tornado-6.1-cp37-cp37m-manylinux2010_x86_64.whl (428 kB)
#      |████████████████████████████████| 428 kB 60.5 MB/s
# Collecting debugpy<2.0,>=1.0.0
#   Downloading debugpy-1.4.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 42.7 MB/s
# Collecting jupyter-client<8.0
#   Downloading jupyter_client-7.0.2-py3-none-any.whl (122 kB)
#      |████████████████████████████████| 122 kB 54.7 MB/s
# Collecting importlib-metadata<5
#   Downloading importlib_metadata-4.8.1-py3-none-any.whl (17 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.5.0-py3-none-any.whl (5.7 kB)
# Collecting typing-extensions>=3.6.4
#   Downloading typing_extensions-3.10.0.2-py3-none-any.whl (26 kB)
# Collecting parso<0.9.0,>=0.8.0
#   Downloading parso-0.8.2-py2.py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 2.4 MB/s
# Collecting jupyter-core>=4.6.0
#   Downloading jupyter_core-4.7.1-py3-none-any.whl (82 kB)
#      |████████████████████████████████| 82 kB 1.2 MB/s
# Collecting python-dateutil>=2.1
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#      |████████████████████████████████| 247 kB 77.7 MB/s
# Collecting entrypoints
#   Downloading entrypoints-0.3-py2.py3-none-any.whl (11 kB)
# Collecting nest-asyncio>=1.5
#   Downloading nest_asyncio-1.5.1-py3-none-any.whl (5.0 kB)
# Collecting pyzmq>=13
#   Downloading pyzmq-22.2.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 72.3 MB/s
# Collecting wheel
#   Using cached wheel-0.37.0-py2.py3-none-any.whl (35 kB)
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 44.7 MB/s
# Collecting pillow>=6.2.0
#   Downloading Pillow-8.3.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 48.5 MB/s
# Collecting pyparsing>=2.2.1
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 6.2 MB/s
# Collecting jsonschema!=2.5.0,>=2.4
#   Downloading jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 4.8 MB/s
# Collecting attrs>=17.4.0
#   Downloading attrs-21.2.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 2.3 MB/s
# Collecting pyrsistent>=0.14.0
#   Downloading pyrsistent-0.18.0-cp37-cp37m-manylinux1_x86_64.whl (119 kB)
#      |████████████████████████████████| 119 kB 62.6 MB/s
# Collecting pytz>=2017.3
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
#      |████████████████████████████████| 510 kB 48.3 MB/s
# Collecting tangled-up-in-unicode==0.1.0
#   Downloading tangled_up_in_unicode-0.1.0-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 43.2 MB/s
# Collecting requests>=2.24.0
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 744 kB/s
# Collecting phik>=0.11.1
#   Downloading phik-0.12.0-cp37-cp37m-manylinux2010_x86_64.whl (675 kB)
#      |████████████████████████████████| 675 kB 70.1 MB/s
# Collecting tqdm>=4.48.2
#   Downloading tqdm-4.62.2-py2.py3-none-any.whl (76 kB)
#      |████████████████████████████████| 76 kB 5.1 MB/s
# Collecting jinja2>=2.11.1
#   Downloading Jinja2-3.0.1-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 60.5 MB/s
# Collecting pydantic>=1.8.1
#   Downloading pydantic-1.8.2-cp37-cp37m-manylinux2014_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 31.0 MB/s
# Collecting visions[type_image_path]==0.7.1
#   Downloading visions-0.7.1-py3-none-any.whl (102 kB)
#      |████████████████████████████████| 102 kB 74.7 MB/s
# Collecting htmlmin>=0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
# Collecting PyYAML>=5.0.0
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 61.6 MB/s
# Collecting missingno>=0.4.2
#   Downloading missingno-0.5.0-py3-none-any.whl (8.8 kB)
# Collecting multimethod==1.4
#   Downloading multimethod-1.4-py2.py3-none-any.whl (7.3 kB)
# Collecting networkx>=2.4
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 49.5 MB/s
# Collecting bottleneck
#   Downloading Bottleneck-1.3.2.tar.gz (88 kB)
#      |████████████████████████████████| 88 kB 7.6 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting imagehash
#   Downloading ImageHash-4.2.1.tar.gz (812 kB)
#      |████████████████████████████████| 812 kB 58.3 MB/s
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.0.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (31 kB)
# Collecting ptyprocess>=0.5
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.0.1-py3-none-any.whl (24 kB)
# Collecting wcwidth
#   Downloading wcwidth-0.2.5-py2.py3-none-any.whl (30 kB)
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.4-py3-none-any.whl (36 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.6-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 60.4 MB/s
# Collecting certifi>=2017.4.17
#   Downloading certifi-2021.5.30-py2.py3-none-any.whl (145 kB)
#      |████████████████████████████████| 145 kB 67.0 MB/s
# Collecting idna<4,>=2.5
#   Downloading idna-3.2-py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 5.2 MB/s
# Collecting thinc<7.5.0,>=7.4.1
#   Downloading thinc-7.4.5-cp37-cp37m-manylinux2014_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 73.2 MB/s
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.5-cp37-cp37m-manylinux2014_x86_64.whl (20 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.5-cp37-cp37m-manylinux2014_x86_64.whl (126 kB)
#      |████████████████████████████████| 126 kB 47.2 MB/s
# Collecting srsly<1.1.0,>=1.0.2
#   Downloading srsly-1.0.5-cp37-cp37m-manylinux2014_x86_64.whl (184 kB)
#      |████████████████████████████████| 184 kB 77.4 MB/s
# Collecting wasabi<1.1.0,>=0.4.0
#   Downloading wasabi-0.8.2-py3-none-any.whl (23 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.5-cp37-cp37m-manylinux2014_x86_64.whl (35 kB)
# Collecting catalogue<1.1.0,>=0.0.7
#   Downloading catalogue-1.0.0-py2.py3-none-any.whl (7.7 kB)
# Collecting plac<1.2.0,>=0.9.6
#   Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Collecting blis<0.8.0,>=0.4.0
#   Downloading blis-0.7.4-cp37-cp37m-manylinux2014_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 71.0 MB/s
# Collecting notebook>=4.4.1
#   Downloading notebook-6.4.3-py3-none-any.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 48.1 MB/s
# Collecting argon2-cffi
#   Downloading argon2_cffi-21.1.0-cp35-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.whl (96 kB)
#      |████████████████████████████████| 96 kB 5.2 MB/s
# Collecting prometheus-client
#   Downloading prometheus_client-0.11.0-py2.py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 4.7 MB/s
# Collecting Send2Trash>=1.5.0
#   Downloading Send2Trash-1.8.0-py3-none-any.whl (18 kB)
# Collecting nbconvert
#   Downloading nbconvert-6.1.0-py3-none-any.whl (551 kB)
#      |████████████████████████████████| 551 kB 54.4 MB/s
# Collecting terminado>=0.8.3
#   Downloading terminado-0.12.1-py3-none-any.whl (15 kB)
# Collecting cffi>=1.0.0
#   Downloading cffi-1.14.6-cp37-cp37m-manylinux1_x86_64.whl (402 kB)
#      |████████████████████████████████| 402 kB 80.7 MB/s
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 72.7 MB/s
# Collecting PyWavelets
#   Downloading PyWavelets-1.1.1-cp37-cp37m-manylinux1_x86_64.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 40.3 MB/s
# Collecting sqlparse>=0.3.1
#   Downloading sqlparse-0.4.2-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.0 MB/s
# Collecting querystring-parser
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Collecting protobuf>=3.7.0
#   Downloading protobuf-3.17.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 46.7 MB/s
# Collecting packaging
#   Downloading packaging-21.0-py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 5.9 MB/s
# Collecting sqlalchemy
#   Downloading SQLAlchemy-1.4.23-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 72.9 MB/s
# Collecting Flask
#   Downloading Flask-2.0.1-py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.9 MB/s
# Collecting prometheus-flask-exporter
#   Downloading prometheus_flask_exporter-0.18.2.tar.gz (22 kB)
# Collecting docker>=4.0.0
#   Downloading docker-5.0.2-py2.py3-none-any.whl (145 kB)
#      |████████████████████████████████| 145 kB 64.7 MB/s
# Collecting databricks-cli>=0.8.7
#   Downloading databricks-cli-0.15.0.tar.gz (56 kB)
#      |████████████████████████████████| 56 kB 3.8 MB/s
# Collecting gitpython>=2.1.0
#   Downloading GitPython-3.1.18-py3-none-any.whl (170 kB)
#      |████████████████████████████████| 170 kB 70.0 MB/s
# Collecting gunicorn
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 8.5 MB/s
# Collecting alembic<=1.4.1
#   Downloading alembic-1.4.1.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 31.5 MB/s
# Collecting cloudpickle
#   Downloading cloudpickle-2.0.0-py3-none-any.whl (25 kB)
# Collecting click>=7.0
#   Downloading click-8.0.1-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 7.1 MB/s
# Collecting Mako
#   Downloading Mako-1.1.5-py2.py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 4.5 MB/s
# Collecting python-editor>=0.3
#   Downloading python_editor-1.0.4-py3-none-any.whl (4.9 kB)
# Collecting tabulate>=0.7.7
#   Downloading tabulate-0.8.9-py3-none-any.whl (25 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.2.1-py2.py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.4 MB/s
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.7-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.7 MB/s
# Collecting smmap<5,>=3.0.1
#   Downloading smmap-4.0.0-py2.py3-none-any.whl (24 kB)
# Collecting greenlet!=0.4.17
#   Downloading greenlet-1.1.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (143 kB)
#      |████████████████████████████████| 143 kB 67.4 MB/s
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Collecting Werkzeug>=2.0
#   Downloading Werkzeug-2.0.1-py3-none-any.whl (288 kB)
#      |████████████████████████████████| 288 kB 69.4 MB/s
# Collecting testpath
#   Downloading testpath-0.5.0-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 3.7 MB/s
# Collecting nbclient<0.6.0,>=0.5.0
#   Downloading nbclient-0.5.4-py3-none-any.whl (66 kB)
#      |████████████████████████████████| 66 kB 4.5 MB/s
# Collecting defusedxml
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting mistune<2,>=0.8.1
#   Downloading mistune-0.8.4-py2.py3-none-any.whl (16 kB)
# Collecting bleach
#   Downloading bleach-4.1.0-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 55.8 MB/s
# Collecting pandocfilters>=1.4.1
#   Downloading pandocfilters-1.4.3.tar.gz (16 kB)
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.1.2-py2.py3-none-any.whl (4.6 kB)
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting regex
#   Downloading regex-2021.8.28-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (745 kB)
#      |████████████████████████████████| 745 kB 56.9 MB/s
# Collecting future
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 59.9 MB/s
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.3.0.tar.gz (1.7 MB)
#      |████████████████████████████████| 1.7 MB 30.5 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
#   Downloading pyLDAvis-3.2.2.tar.gz (1.7 MB)
#      |████████████████████████████████| 1.7 MB 44.0 MB/s
# Collecting numexpr
#   Downloading numexpr-2.7.3-cp37-cp37m-manylinux2010_x86_64.whl (471 kB)
#      |████████████████████████████████| 471 kB 62.9 MB/s
# Collecting funcy
#   Downloading funcy-1.16-py2.py3-none-any.whl (32 kB)
# Collecting numba>=0.35
#   Downloading numba-0.54.0-2-cp37-cp37m-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 41.0 MB/s
# Collecting statsmodels
#   Downloading statsmodels-0.12.2-cp37-cp37m-manylinux1_x86_64.whl (9.5 MB)
#      |████████████████████████████████| 9.5 MB 36.1 MB/s
# Collecting llvmlite<0.38,>=0.37.0rc1
#   Downloading llvmlite-0.37.0-cp37-cp37m-manylinux2014_x86_64.whl (26.3 MB)
#      |████████████████████████████████| 26.3 MB 82 kB/s
# Collecting patsy>=0.5
#   Downloading patsy-0.5.1-py2.py3-none-any.whl (231 kB)
#      |████████████████████████████████| 231 kB 67.3 MB/s
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.4.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 49.1 MB/s
# Building wheels for collected packages: cufflinks, htmlmin, bottleneck, imagehash, alembic, databricks-cli, pandocfilters, prometheus-flask-exporter, pyLDAvis, future, pyod, umap-learn, pynndescent
#   Building wheel for cufflinks (setup.py) ... done
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=67917 sha256=eea95053f3ef4167b24421f28b3545839693e0123a6fc5f822bcfe49fd4f100a
#   Stored in directory: /root/.cache/pip/wheels/e1/27/13/3fe67fa7ea7be444b831d117220b3b586b872c9acd4df480d0
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27098 sha256=967565679d86a0a84b3c7e5c81764aca4c185b630d81ea9ce8db9bcf8bbf8b83
#   Stored in directory: /root/.cache/pip/wheels/70/e1/52/5b14d250ba868768823940c3229e9950d201a26d0bd3ee8655
#   Building wheel for bottleneck (PEP 517) ... done
#   Created wheel for bottleneck: filename=Bottleneck-1.3.2-cp37-cp37m-linux_x86_64.whl size=334901 sha256=c11e761d707f910224dba52ca92838427b321904bfe8a5c87bde21538efccc4c
#   Stored in directory: /root/.cache/pip/wheels/87/85/9c/a325c89ff0498660ef8a335fb4b3912939c273ea4f094af29f
#   Building wheel for imagehash (setup.py) ... done
#   Created wheel for imagehash: filename=ImageHash-4.2.1-py2.py3-none-any.whl size=295207 sha256=88f7f8c66135c4f8a23f950d4ea4e6edf8c740811d29d942960854c2f6c8dfa4
#   Stored in directory: /root/.cache/pip/wheels/4c/d5/59/5e3e297533ddb09407769762985d134135064c6831e29a914e
#   Building wheel for alembic (setup.py) ... done
#   Created wheel for alembic: filename=alembic-1.4.1-py2.py3-none-any.whl size=158172 sha256=04c63755fe72819fc15a7f784fb53bab52d046a78b11f5c63ce9ea183ec746f5
#   Stored in directory: /root/.cache/pip/wheels/be/5d/0a/9e13f53f4f5dfb67cd8d245bb7cdffe12f135846f491a283e3
#   Building wheel for databricks-cli (setup.py) ... done
#   Created wheel for databricks-cli: filename=databricks_cli-0.15.0-py3-none-any.whl size=105260 sha256=48a611e1d62ceae0f78fcd3317bf353bb8fa777e559fdd951f772d16149bbc30
#   Stored in directory: /root/.cache/pip/wheels/e7/ba/75/284f9a90ff7a010bb23b9798f2e9a19dd9fe619379c917bff4
#   Building wheel for pandocfilters (setup.py) ... done
#   Created wheel for pandocfilters: filename=pandocfilters-1.4.3-py3-none-any.whl size=8006 sha256=be7b80f126e3c152aa8654d67abb82e19246d5f1143d4921a9f5a79d2bb2813f
#   Stored in directory: /root/.cache/pip/wheels/42/81/34/545dc2fbf0e9137811e901108d37fc04650e81d48f97078000
#   Building wheel for prometheus-flask-exporter (setup.py) ... done
#   Created wheel for prometheus-flask-exporter: filename=prometheus_flask_exporter-0.18.2-py3-none-any.whl size=17415 sha256=8af975d06b551a4a48591a794ac104972a4e218e6f3699d4b2025e7fd3bc9b7c
#   Stored in directory: /root/.cache/pip/wheels/6a/1e/1c/c765920cb92b2f0343d2dd8b481a407cee2823f9b4bbd2e52a
#   Building wheel for pyLDAvis (setup.py) ... done
#   Created wheel for pyLDAvis: filename=pyLDAvis-3.2.2-py2.py3-none-any.whl size=135618 sha256=9d3d64ddb410d1e009a371ca76ad5428b443f2516b11c18c85c32a512a40047f
#   Stored in directory: /root/.cache/pip/wheels/f8/b1/9b/560ac1931796b7303f7b517b949d2d31a4fbc512aad3b9f284
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=806edf7b4a90d4f562bd258026412c9375fcab1cd5fec74666174515b1ebbac9
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
#   Building wheel for pyod (setup.py) ... done
#   Created wheel for pyod: filename=pyod-0.9.3-py3-none-any.whl size=130719 sha256=918a25d63a04d3c6eb9a2513b016ca61c392bfecb1ce8e7a8bf49bb195c29abf
#   Stored in directory: /root/.cache/pip/wheels/ac/94/65/d29b87d4ad6defcec32686063e9bbaf5907a259eb2d8342174
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.1-py3-none-any.whl size=76564 sha256=bb4d0f21d305e28a83224d2951d78076a1e0160649bea28fe641abb997f42d29
#   Stored in directory: /root/.cache/pip/wheels/01/e7/bb/347dc0e510803d7116a13d592b10cc68262da56a8eec4dd72f
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.4-py3-none-any.whl size=52373 sha256=b45eb38b82280bcb9a3694369ba0a4f5e3e4cacc16a934e16b9fc0aad1f6077c
#   Stored in directory: /root/.cache/pip/wheels/d0/5b/62/3401692ddad12324249c774c4b15ccb046946021e2b581c043
# Successfully built cufflinks htmlmin bottleneck imagehash alembic databricks-cli pandocfilters prometheus-flask-exporter pyLDAvis future pyod umap-learn pynndescent
# Installing collected packages: zipp, typing-extensions, traitlets, six, setuptools, pyrsistent, importlib-metadata, attrs, wcwidth, tornado, pyzmq, python-dateutil, pyparsing, ptyprocess, parso, nest-asyncio, jupyter-core, jsonschema, ipython-genutils, entrypoints, webencodings, pygments, pycparser, prompt-toolkit, pickleshare, pexpect, packaging, nbformat, matplotlib-inline, MarkupSafe, jupyter-client, jedi, decorator, backcall, testpath, pandocfilters, nbclient, mistune, jupyterlab-pygments, jinja2, IPython, defusedxml, debugpy, cffi, bleach, argcomplete, terminado, Send2Trash, pytz, prometheus-client, pillow, numpy, nbconvert, kiwisolver, ipykernel, cycler, argon2-cffi, Werkzeug, urllib3, threadpoolctl, tangled-up-in-unicode, smmap, scipy, PyWavelets, pandas, notebook, networkx, murmurhash, multimethod, matplotlib, llvmlite, joblib, itsdangerous, idna, greenlet, cymem, click, charset-normalizer, certifi, bottleneck, widgetsnbextension, websocket-client, wasabi, visions, tqdm, tenacity, tabulate, srsly, sqlalchemy, seaborn, scikit-learn, requests, regex, python-editor, preshed, plac, patsy, numba, Mako, jupyterlab-widgets, imagehash, gitdb, Flask, catalogue, blis, wheel, thinc, statsmodels, sqlparse, smart-open, querystring-parser, PyYAML, pynndescent, pydantic, protobuf, prometheus-flask-exporter, plotly, phik, numexpr, nltk, missingno, ipywidgets, htmlmin, gunicorn, gitpython, future, funcy, docker, databricks-cli, colorlover, cloudpickle, alembic, yellowbrick, wordcloud, umap-learn, textblob, spacy, scikit-plot, pyod, pyLDAvis, pandas-profiling, mlxtend, mlflow, lightgbm, kmodes, imbalanced-learn, gensim, cufflinks, Boruta, pycaret
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.6.0 requires six~=1.15.0, but you have six 1.16.0 which is incompatible.
# tensorflow 2.6.0 requires typing-extensions~=3.7.4, but you have typing-extensions 3.10.0.2 which is incompatible.
# moviepy 0.2.3.5 requires decorator<5.0,>=4.0.2, but you have decorator 5.1.0 which is incompatible.
# jupyter-console 5.2.0 requires prompt-toolkit<2.0.0,>=1.0.0, but you have prompt-toolkit 3.0.20 which is incompatible.
# gym 0.17.3 requires cloudpickle<1.7.0,>=1.2.0, but you have cloudpickle 2.0.0 which is incompatible.
# google-colab 1.0.0 requires ipykernel~=4.10, but you have ipykernel 6.4.1 which is incompatible.
# google-colab 1.0.0 requires ipython~=5.5.0, but you have ipython 7.27.0 which is incompatible.
# google-colab 1.0.0 requires notebook~=5.3.0; python_version >= "3.0", but you have notebook 6.4.3 which is incompatible.
# google-colab 1.0.0 requires pandas~=1.1.0; python_version >= "3.0", but you have pandas 1.3.2 which is incompatible.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.26.0 which is incompatible.
# google-colab 1.0.0 requires six~=1.15.0, but you have six 1.16.0 which is incompatible.
# google-colab 1.0.0 requires tornado~=5.1.0; python_version >= "3.0", but you have tornado 6.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed Boruta-0.3 Flask-2.0.1 IPython-7.27.0 Mako-1.1.5 MarkupSafe-2.0.1 PyWavelets-1.1.1 PyYAML-5.4.1 Send2Trash-1.8.0 Werkzeug-2.0.1 alembic-1.4.1 argcomplete-1.12.3 argon2-cffi-21.1.0 attrs-21.2.0 backcall-0.2.0 bleach-4.1.0 blis-0.7.4 bottleneck-1.3.2 catalogue-1.0.0 certifi-2021.5.30 cffi-1.14.6 charset-normalizer-2.0.4 click-8.0.1 cloudpickle-2.0.0 colorlover-0.3.0 cufflinks-0.17.3 cycler-0.10.0 cymem-2.0.5 databricks-cli-0.15.0 debugpy-1.4.3 decorator-5.1.0 defusedxml-0.7.1 docker-5.0.2 entrypoints-0.3 funcy-1.16 future-0.18.2 gensim-3.8.3 gitdb-4.0.7 gitpython-3.1.18 greenlet-1.1.1 gunicorn-20.1.0 htmlmin-0.1.12 idna-3.2 imagehash-4.2.1 imbalanced-learn-0.7.0 importlib-metadata-4.8.1 ipykernel-6.4.1 ipython-genutils-0.2.0 ipywidgets-7.6.4 itsdangerous-2.0.1 jedi-0.18.0 jinja2-3.0.1 joblib-1.0.1 jsonschema-3.2.0 jupyter-client-7.0.2 jupyter-core-4.7.1 jupyterlab-pygments-0.1.2 jupyterlab-widgets-1.0.1 kiwisolver-1.3.2 kmodes-0.11.0 lightgbm-3.2.1 llvmlite-0.37.0 matplotlib-3.4.3 matplotlib-inline-0.1.3 missingno-0.5.0 mistune-0.8.4 mlflow-1.20.2 mlxtend-0.19.0 multimethod-1.4 murmurhash-1.0.5 nbclient-0.5.4 nbconvert-6.1.0 nbformat-5.1.3 nest-asyncio-1.5.1 networkx-2.6.3 nltk-3.6.2 notebook-6.4.3 numba-0.54.0 numexpr-2.7.3 numpy-1.19.5 packaging-21.0 pandas-1.3.2 pandas-profiling-3.0.0 pandocfilters-1.4.3 parso-0.8.2 patsy-0.5.1 pexpect-4.8.0 phik-0.12.0 pickleshare-0.7.5 pillow-8.3.2 plac-1.1.3 plotly-5.3.1 preshed-3.0.5 prometheus-client-0.11.0 prometheus-flask-exporter-0.18.2 prompt-toolkit-3.0.20 protobuf-3.17.3 ptyprocess-0.7.0 pyLDAvis-3.2.2 pycaret-2.3.3 pycparser-2.20 pydantic-1.8.2 pygments-2.10.0 pynndescent-0.5.4 pyod-0.9.3 pyparsing-2.4.7 pyrsistent-0.18.0 python-dateutil-2.8.2 python-editor-1.0.4 pytz-2021.1 pyzmq-22.2.1 querystring-parser-1.2.4 regex-2021.8.28 requests-2.26.0 scikit-learn-0.23.2 scikit-plot-0.3.7 scipy-1.5.4 seaborn-0.11.2 setuptools-58.0.4 six-1.16.0 smart-open-5.2.1 smmap-4.0.0 spacy-2.3.7 sqlalchemy-1.4.23 sqlparse-0.4.2 srsly-1.0.5 statsmodels-0.12.2 tabulate-0.8.9 tangled-up-in-unicode-0.1.0 tenacity-8.0.1 terminado-0.12.1 testpath-0.5.0 textblob-0.15.3 thinc-7.4.5 threadpoolctl-2.2.0 tornado-6.1 tqdm-4.62.2 traitlets-5.1.0 typing-extensions-3.10.0.2 umap-learn-0.5.1 urllib3-1.26.6 visions-0.7.1 wasabi-0.8.2 wcwidth-0.2.5 webencodings-0.5.1 websocket-client-1.2.1 wheel-0.37.0 widgetsnbextension-3.5.1 wordcloud-1.8.1 yellowbrick-1.3.post1 zipp-3.5.0
# WARNING: Target directory /content/notebooks/bin already exists. Specify --upgrade to force replacement.

# %%
pycaret
fastapi
uvicorn
streamlit
flask
scikit-learn==0.23.2
sweetviz
shap
xgboost
catboost
numpy==1.19.5
tensorflow
transformers
dask
dask_ml

# %%
# !pip install --target=$nb_path fastapi, uvicorn
# Out:
# ERROR: Invalid requirement: 'fastapi,'

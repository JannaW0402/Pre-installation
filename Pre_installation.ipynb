# %%
import os, sys
from google.colab import drive
drive.mount('/content/drive')
nb_path = '/content/notebooks'
os.symlink('/content/drive/My Drive/Colab Notebooks', nb_path)
sys.path.insert(0,nb_path)
# Out:
# Mounted at /content/drive

# %%
# !pip install --target=$nb_path --upgrade pip
# Out:
# ...
#   Using cached pip-21.2.4-py3-none-any.whl (1.6 MB)
# ...

# %%
# !pip uninstall --target=$nb_path tensorflow -y
# !pip install --target=$nb_path gast==0.3.2
# !pip install --target=$nb_path tensorflow
# Out:
# Usage:
#   pip3 uninstall [options] <package> ...
#   pip3 uninstall [options] -r <requirements file> ...
#
# no such option: --target
# ...
#   Created wheel for gast: filename=gast-0.3.2-py3-none-any.whl size=9693 sha256=ae3a0601ee78866169d379f8418286b15d9718fac4c3c02abff6d29b90dd66fc
#   Stored in directory: /root/.cache/pip/wheels/9b/7b/89/365a82e420c11db9b43d34918045faa8004748a1d97597930d
# Successfully built gast
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.6.0 requires gast==0.4.0, but you have gast 0.3.2 which is incompatible.
# ...
# WARNING: Target directory /content/notebooks/gast already exists. Specify --upgrade to force replacement.
# ...
#      |████████████████████████████████| 458.3 MB 9.0 kB/s
# ...
#      |████████████████████████████████| 1.3 MB 69.0 MB/s
# ...
#      |████████████████████████████████| 462 kB 59.0 MB/s
# ...

# %%
# !pip install --target=$nb_path six~=1.15.0
# Out:
# ...
#   Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.26.0 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# ...
# WARNING: Target directory /content/notebooks/six.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /content/notebooks/__pycache__ already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /content/notebooks/six-1.15.0.dist-info already exists. Specify --upgrade to force replacement.

# %%
# !pip install --target=$nb_path typing-extensions~=3.7.4
# Out:
# ...
#   Using cached typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# ...
# WARNING: Target directory /content/notebooks/typing_extensions-3.7.4.3.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /content/notebooks/__pycache__ already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /content/notebooks/typing_extensions.py already exists. Specify --upgrade to force replacement.

# %%
# !pip install --target=$nb_path decorator<5.0,>=4.0.2
# !pip install --target=$nb_path prompt-toolkit<2.0.0,>=1.0.0
# Out:
# /bin/bash: 5.0,: No such file or directory
# /bin/bash: 2.0.0,: No such file or directory

# %%
# !pip install --target=$nb_path cloudpickle<1.7.0,>=1.2.0
# Out:
# /bin/bash: 1.7.0,: No such file or directory

# %%
# !pip install --target=$nb_path  google.colab
# Out:
# ...
#   Using cached google_colab-1.0.0-py2.py3-none-any.whl
# ...
#   Using cached google_auth-1.4.2-py2.py3-none-any.whl (64 kB)
# ...
#   Using cached six-1.12.0-py2.py3-none-any.whl (10 kB)
# ...
#   Using cached tornado-4.5.3-cp37-cp37m-linux_x86_64.whl
# ...
#   Using cached portpicker-1.2.0-py3-none-any.whl
# ...
#   Using cached ipython-5.5.0-py3-none-any.whl (758 kB)
# ...
#   Using cached notebook-5.2.2-py2.py3-none-any.whl (8.0 MB)
# ...
#   Using cached pandas-0.24.2-cp37-cp37m-manylinux1_x86_64.whl (10.1 MB)
# ...
#   Using cached ipykernel-4.6.1-py3-none-any.whl (104 kB)
# ...
#   Using cached requests-2.21.0-py2.py3-none-any.whl (57 kB)
# ...
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# ...
#   Using cached rsa-4.7.2-py3-none-any.whl (34 kB)
# ...
#   Using cached cachetools-4.2.2-py3-none-any.whl (11 kB)
# ...
#   Using cached jupyter_client-7.0.3-py3-none-any.whl (122 kB)
# ...
#   Using cached traitlets-5.1.0-py3-none-any.whl (101 kB)
# ...
#   Using cached decorator-5.1.0-py3-none-any.whl (9.1 kB)
# ...

# %%
# !pip install --target=$nb_path folium==0.2.1
# !pip install --target=$nb_path imgaug<0.2.7,>=0.2.5
# Out:
# ...
#   Using cached folium-0.2.1-py3-none-any.whl
# ...
#   Using cached Jinja2-3.0.1-py3-none-any.whl (133 kB)
# ...
#   Using cached MarkupSafe-2.0.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (31 kB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.26.0 which is incompatible.
# flask 1.1.4 requires Jinja2<3.0,>=2.10.1, but you have jinja2 3.0.1 which is incompatible.
# ...
# WARNING: Target directory /content/notebooks/Jinja2-3.0.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /content/notebooks/folium-0.2.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /content/notebooks/jinja2 already exists. Specify --upgrade to force replacement.
# ...

# %%
google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.26.0 which is incompatible.
datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.

# %%
# !pip install --target=$nb_path pycaret
# Out:
# ...
#   Using cached pycaret-2.3.3-py3-none-any.whl (264 kB)
# ...
#   Using cached ipywidgets-7.6.5-py2.py3-none-any.whl (121 kB)
# ...
#   Using cached seaborn-0.11.2-py3-none-any.whl (292 kB)
# ...
#   Using cached pandas_profiling-3.0.0-py2.py3-none-any.whl (248 kB)
# ...
#   Using cached matplotlib-3.4.3-cp37-cp37m-manylinux1_x86_64.whl (10.3 MB)
# ...
#   Using cached wordcloud-1.8.1-cp37-cp37m-manylinux1_x86_64.whl (366 kB)
# ...
#   Using cached ipython-7.27.0-py3-none-any.whl (787 kB)
# ...
#   Using cached mlxtend-0.19.0-py2.py3-none-any.whl (1.3 MB)
# ...
#   Using cached lightgbm-3.2.1-py3-none-manylinux1_x86_64.whl (2.0 MB)
# ...
#   Using cached mlflow-1.20.2-py3-none-any.whl (14.6 MB)
# ...
#   Using cached spacy-2.3.7-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.4 MB)
# ...
#   Using cached textblob-0.15.3-py2.py3-none-any.whl (636 kB)
# ...
#   Using cached pyLDAvis-3.3.1.tar.gz (1.7 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
# ...

# %%
from pycaret.classification import *

# %%
pycaret
fastapi
uvicorn
streamlit
flask
scikit-learn==0.23.2
sweetviz
shap
xgboost
catboost
numpy==1.19.5
tensorflow
transformers
dask
dask_ml

# %%
# !pip install --target=$nb_path fastapi

# %%
# !pip install --target=$nb_path tensorflow

# %%
# !pip install --target=$nb_path uvicorn
